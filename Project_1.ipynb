# %%
import pandas as pd
df = pd.read_csv('Weather_Data.csv')

# %% [markdown]
# # 1. Find all unique 'wind speed' values in data

# %%
df.head()
var = df['Wind Speed_km/h'].nunique()
print('Ans:', var)
# Out:
# Ans: 34

# %% [markdown]
# # 2. Find the number of times when the Weather is exactly clear

# %%
df.head()
var=df[df['Weather']=="Clear"]
var.value_counts()
print('ans:', var)

# or can use groupby
df.groupby('Weather').get_group('Clear')
# Out:
# ans:              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %% [markdown]
# # 3. Find the number of times when the 'wind speed is exactly 4km/h'

# %%
df.head()
df[df['Wind Speed_km/h'] == 4]

#or

df.groupby('Wind Speed_km/h').get_group(4)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %% [markdown]
# # 4. Find the all null values from the dataset

# %%
df.head()
df[df.isnull()]
# df[df.notnull()] # or use notnull
var = len(df)
print("Answer of Null Values:",var)
# Out:
# Answer of Null Values: 8784

# %% [markdown]
# # 5. Rename the column Weather to Weather Condtion

# %%
df.head()
df.rename(columns={"Weather":"Weather Condition"}, inplace=True) #inplace true is optional to permanently rename it

# %% [markdown]
# # 6. What was the mean of 'visibility_km'?

# %%
df['Visibility_km'].mean()
# Out:
# 27.664446721311478

# %% [markdown]
# # 7. What is the standard deviation of pressure in this data?

# %%
df['Press_kPa'].std()
# Out:
# 0.8440047459486474

# %% [markdown]
# # 8. What is the variance of Relative Humidity in this data?

# %%
df['Rel Hum_%'].var()
# Out:
# 286.2485501984998

# %% [markdown]
# # 9. Find all instances when Snow was recorded?

# %%
df.head()
snow=df[df['Weather Condition']=='Snow']
var = len(snow)
print("Total no. of columns that have snow listed:",var)
# Out:
# Total no. of columns that have snow listed: 390

# %% [markdown]
# # 10. Find all instances when Wind Speed is above 24 and Visibility is 25

# %%
df.head()
var=df[(df['Wind Speed_km/h'] > 24) & (df['Visibility_km']==25)]
len(var)
# Out:
# 308

# %% [markdown]
# # 11. What is the mean value of each column against each weather condition?

# %%
df.head()
df.groupby('Weather Condition').mean()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather Condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %% [markdown]
# # 12. What is the minimum and maximum value of each column against each weather condition?

# %%
df.head()
min=df.groupby("Weather Condition").min()
print(min)

max=df.groupby("Weather Condition").max()
print(max)
# Out:
#                                                 Date/Time  Temp_C  \
# Weather Condition
# Clear                                      1/11/2012 1:00   -23.3
# Cloudy                                     1/1/2012 17:00   -21.4
# Drizzle                                   1/23/2012 21:00     1.1
# Drizzle,Fog                               1/23/2012 20:00     0.0
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/17/2012 15:00     0.9
# Drizzle,Snow,Fog                         12/18/2012 21:00     0.3
# Fog                                         1/1/2012 0:00   -16.0
# Freezing Drizzle                          1/13/2012 10:00    -9.0
# Freezing Drizzle,Fog                        1/1/2012 2:00    -6.4
# Freezing Drizzle,Haze                      2/1/2012 11:00    -5.8
# Freezing Drizzle,Snow                      1/13/2012 3:00    -8.3
# Freezing Fog                               1/22/2012 6:00   -19.0
# ...

# %% [markdown]
# # 13. Show all the reports where weather condition is fog.

# %%
df.head()
var=df[df["Weather Condition"]=='Fog']
len(var)
# Out:
# 150

# %% [markdown]
# # 14. Find all instances when 'Weather is clear' or 'Visibility is above 40'

# %%
df.head()
var=df[(df['Weather Condition']=='Clear') | (df['Visibility_km']>40)]
len(var)
# Out:
# 3027

# %% [markdown]
# # 15. Find all instances when:
# ### 'weather is clear' and 'relative humidity is greater than 50'
# ### or
# ### 'visibitlity is above 40'

# %%
df.head()
check=df[((df['Weather Condition']=='Clear') & (df['Rel Hum_%']>50)) | (df['Visibility_km']>40)]
len(check)
# Out:
# 2921
